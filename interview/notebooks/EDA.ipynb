# %%
cd src
# Out:
# /Users/jbud/Desktop/Galvanize/repos/copy/supervised-learning-case-study/interview/src

# %%
run main.py

# %%
import matplotlib.pyplot as plt

# %%
df
# Out:
#            Date  Company         Industry Location             Position  \
# 0    2015-02-13  Hospira  Pharmaceuticals  chennai  Production- Sterile
# 1    2015-02-13  Hospira  Pharmaceuticals  chennai  Production- Sterile
# 2    2000-01-01       Na               Na       na                   Na
# 3    2015-02-13  Hospira  Pharmaceuticals  chennai  Production- Sterile
# 4    2015-02-13  Hospira  Pharmaceuticals  chennai  Production- Sterile
# ...         ...      ...              ...      ...                  ...
# 1228 2016-07-05   Pfizer  Pharmaceuticals  chennai                Niche
# 1229 2016-07-05   Pfizer  Pharmaceuticals  chennai                Niche
# 1230 2016-06-05   Pfizer  Pharmaceuticals  chennai                Niche
# 1231 2016-06-05   Pfizer  Pharmaceuticals  chennai                Niche
# 1232 2000-01-01       Na               Na       na                   Na
#
#                 Skillset    Interview Type Gender Candidate Job Location  \
# ...

# %%
plt.hist(df['Date'])
# Out:
# (array([   9.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,    0.,
#         1224.]),
#  array([612411.0088327 , 625019.20794943, 637627.40706616, 650235.60618289,
#         662843.80529962, 675452.00441635, 688060.20353308, 700668.40264981,
#         713276.60176654, 725884.80088327, 738493.        ]),
#  <a list of 10 Patch objects>)

# %%
df['Date'].min()
# Out:
# Timestamp('2000-01-01 00:00:00')

# %%
df['Date'].unique()
# Out:
# array(['2015-02-13T00:00:00.000000000', '2000-01-01T00:00:00.000000000',
#        '2015-06-19T00:00:00.000000000', '2015-06-23T00:00:00.000000000',
#        '2015-06-29T00:00:00.000000000', '2015-06-25T00:00:00.000000000',
#        '2016-05-25T00:00:00.000000000', '2016-04-12T00:00:00.000000000',
#        '2016-04-13T00:00:00.000000000', '2016-02-27T00:00:00.000000000',
#        '2016-07-05T00:00:00.000000000', '2016-05-05T00:00:00.000000000',
#        '2016-04-05T00:00:00.000000000', '2016-04-21T00:00:00.000000000',
#        '2016-04-22T00:00:00.000000000', '2016-04-23T00:00:00.000000000',
#        '2016-04-15T00:00:00.000000000', '2016-04-19T00:00:00.000000000',
#        '2016-04-20T00:00:00.000000000', '2016-04-25T00:00:00.000000000',
#        '2016-04-18T00:00:00.000000000', '2016-11-05T00:00:00.000000000',
#        '2016-10-05T00:00:00.000000000', '2017-12-04T00:00:00.000000000',
#        '2018-12-04T00:00:00.000000000', '2019-12-04T00:00:00.000000000',
# ...
